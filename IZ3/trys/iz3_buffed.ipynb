# %%
import os

os.environ["TF_GPU_ALLOCATOR"] = "cuda_malloc_async"

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from sklearn.metrics import accuracy_score, precision_score, recall_score
from keras_preprocessing.image import ImageDataGenerator

from tensorflow import keras
from tensorflow.keras import layers

import nibabel as nib

from scipy import ndimage


def read_nifti_file(filepath):
    """Read and load volume"""
    # Read file
    scan = nib.load(filepath)
    # Get raw data
    scan = scan.get_fdata()
    return scan


def normalize(volume):
    """Normalize the volume"""
    min = -1000
    max = 400
    volume[volume < min] = min
    volume[volume > max] = max
    volume = (volume - min) / (max - min)
    volume = volume.astype("float32")
    return volume


def resize_volume(img):
    """Resize across z-axis"""
    # Set the desired depth
    desired_depth = 64
    desired_width = 128
    desired_height = 128
    # Get current depth
    current_depth = img.shape[-1]
    current_width = img.shape[0]
    current_height = img.shape[1]
    # Compute depth factor
    depth = current_depth / desired_depth
    width = current_width / desired_width
    height = current_height / desired_height
    depth_factor = 1 / depth
    width_factor = 1 / width
    height_factor = 1 / height
    # Rotate
    img = ndimage.rotate(img, 90, reshape=False)
    # Resize across z-axis
    img = ndimage.zoom(img, (width_factor, height_factor, depth_factor), order=1)
    return img


def process_scan(path):
    """Read and resize volume"""
    # Read scan
    volume = read_nifti_file(path)
    # Normalize
    volume = normalize(volume)
    # Resize width, height and depth
    volume = resize_volume(volume)
    return volume


# Тестим наличие видиокарты
from tensorflow.python.client import device_lib
import tensorflow as tf

gpus = tf.config.experimental.list_physical_devices("GPU")
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
            print(tf.config.experimental.get_memory_info("GPU:0")["current"])
        logical_gpus = tf.config.experimental.list_logical_devices("GPU")
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        print(e)
# Out:
# 0
# 1 Physical GPUs, 1 Logical GPUs

# %%
normal_scan_folder = "parsed_data/good"
abnormal_scan_folder = "parsed_data/bad"
# Folder "CT-0" consist of CT scans having normal lung tissue,
# no CT-signs of viral pneumonia.
normal_scan_paths = [
    os.path.join(os.getcwd(), normal_scan_folder, x)
    for x in os.listdir(normal_scan_folder)
]
# Folder "CT-23" consist of CT scans having several ground-glass opacifications,
# involvement of lung parenchyma.
abnormal_scan_paths = [
    os.path.join(os.getcwd(), abnormal_scan_folder, x)
    for x in os.listdir(abnormal_scan_folder)
]

print("CT scans with normal lung tissue: " + str(len(normal_scan_paths)))
print("CT scans with abnormal lung tissue: " + str(len(abnormal_scan_paths)))

normal_scan_paths = normal_scan_paths[:100]
abnormal_scan_paths = abnormal_scan_paths[:100]

# Read and process the scans.
# Each scan is resized across height, width, and depth and rescaled.
abnormal_scans = np.array([process_scan(path) for path in abnormal_scan_paths])
normal_scans = np.array([process_scan(path) for path in normal_scan_paths])


import pickle

state_to_save = {
    'abnormal_scans': abnormal_scans,
    'normal_scans': normal_scans,
}

with open('200saved_state333.pickle', 'wb') as file:
    pickle.dump(state_to_save, file)
# Out:
# CT scans with normal lung tissue: 194
# CT scans with abnormal lung tissue: 192
# Number of samples in train and validation are 140 and 60.

# %%
with open('200saved_state333.pickle', 'rb') as file:
    loaded_state = pickle.load(file)

abnormal_scans = loaded_state['abnormal_scans']
normal_scans = loaded_state['normal_scans']

# For the CT scans having presence of viral pneumonia
# assign 1, for the normal ones assign 0.
abnormal_labels = np.array([1 for _ in range(len(abnormal_scans))])
normal_labels = np.array([0 for _ in range(len(normal_scans))])

# Split data in the ratio 70-30 for training and validation.
x_train = np.concatenate((abnormal_scans[:70], normal_scans[:70]), axis=0)
y_train = np.concatenate((abnormal_labels[:70], normal_labels[:70]), axis=0)
x_val = np.concatenate((abnormal_scans[70:], normal_scans[70:]), axis=0)
y_val = np.concatenate((abnormal_labels[70:], normal_labels[70:]), axis=0)
print(
    "Number of samples in train and validation are %d and %d."
    % (x_train.shape[0], x_val.shape[0])
)
# Out:
# Number of samples in train and validation are 140 and 60.

# %%
import random
from scipy import ndimage


@tf.function
def rotate(volume):
    """Rotate the volume by a few degrees"""

    def scipy_rotate(volume):
        # define some rotation angles
        angles = [-20, -10, -5, 5, 10, 20]
        # pick angles at random
        angle = random.choice(angles)
        # rotate volume
        volume = ndimage.rotate(volume, angle, reshape=False)
        volume[volume < 0] = 0
        volume[volume > 1] = 1
        return volume

    augmented_volume = tf.numpy_function(scipy_rotate, [volume], tf.float32)
    return augmented_volume


def train_preprocessing(volume, label):
    """Process training data by rotating and adding a channel."""
    # Rotate volume
    volume = rotate(volume)
    volume = tf.expand_dims(volume, axis=3)
    return volume, label


def validation_preprocessing(volume, label):
    """Process validation data by only adding a channel."""
    volume = tf.expand_dims(volume, axis=3)
    return volume, label


print(tf.config.experimental.get_memory_info("GPU:0")["current"])
# Define data loaders.
train_loader = tf.data.Dataset.from_tensor_slices((x_train, y_train))
validation_loader = tf.data.Dataset.from_tensor_slices((x_val, y_val))


batch_size = 2
# Augment the on the fly during training.
train_dataset = (
    train_loader.shuffle(len(x_train))
    .map(train_preprocessing)
    .batch(batch_size)
    .prefetch(2)
)
# Only rescale.
validation_dataset = (
    validation_loader.shuffle(len(x_val))
    .map(validation_preprocessing)
    .batch(batch_size)
    .prefetch(2)
)

def get_model(width=128, height=128, depth=64):
    """Build a 3D convolutional neural network model."""

    inputs = keras.Input((width, height, depth, 1))

    x = layers.Conv3D(filters=64, kernel_size=3, activation="relu")(inputs)
    x = layers.MaxPool3D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)

    x = layers.Conv3D(filters=64, kernel_size=3, activation="relu")(x)
    x = layers.MaxPool3D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)

    x = layers.Conv3D(filters=128, kernel_size=3, activation="relu")(x)
    x = layers.MaxPool3D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)

    x = layers.Conv3D(filters=256, kernel_size=3, activation="relu")(x)
    x = layers.MaxPool3D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)

    x = layers.GlobalAveragePooling3D()(x)
    x = layers.Dense(units=512, activation="relu")(x)
    x = layers.Dropout(0.3)(x)

    outputs = layers.Dense(units=1, activation="sigmoid")(x)

    # Define the model.
    model = keras.Model(inputs, outputs, name="3dcnn")
    return model


# Build model.
model = get_model(width=128, height=128, depth=64)
model.summary()
# Out:
# 0
# Model: "3dcnn"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 64, 1)  0
#                              ]
#
#  conv3d (Conv3D)             (None, 126, 126, 62, 64)  1792
#
#  max_pooling3d (MaxPooling3D  (None, 63, 63, 31, 64)   0
#  )
#
#  batch_normalization (BatchN  (None, 63, 63, 31, 64)   256
#  ormalization)
#
#  conv3d_1 (Conv3D)           (None, 61, 61, 29, 64)    110656
#
#  max_pooling3d_1 (MaxPooling  (None, 30, 30, 14, 64)   0
#  3D)
#
#  batch_normalization_1 (Batc  (None, 30, 30, 14, 64)   256
#  hNormalization)
#
#  conv3d_2 (Conv3D)           (None, 28, 28, 12, 128)   221312
#
#  max_pooling3d_2 (MaxPooling  (None, 14, 14, 6, 128)   0
#  3D)
#
#  batch_normalization_2 (Batc  (None, 14, 14, 6, 128)   512
#  hNormalization)
#
#  conv3d_3 (Conv3D)           (None, 12, 12, 4, 256)    884992
#
#  max_pooling3d_3 (MaxPooling  (None, 6, 6, 2, 256)     0
#  3D)
#
#  batch_normalization_3 (Batc  (None, 6, 6, 2, 256)     1024
#  hNormalization)
#
#  global_average_pooling3d (G  (None, 256)              0
#  lobalAveragePooling3D)
#
#  dense (Dense)               (None, 512)               131584
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 1,352,897
# Trainable params: 1,351,873
# Non-trainable params: 1,024
# _________________________________________________________________

# %%
# Показ снимков
data = train_dataset.take(1)
images, labels = list(data)[0]
images = images.numpy()
image = images[0]
print("Dimension of the CT scan is:", image.shape)
plt.imshow(np.squeeze(image[:, :, 30]), cmap="gray")

def plot_slices(num_rows, num_columns, width, height, data):
    """Plot a montage of 20 CT slices"""
    data = np.rot90(np.array(data))
    data = np.transpose(data)
    data = np.reshape(data, (num_rows, num_columns, width, height))
    rows_data, columns_data = data.shape[0], data.shape[1]
    heights = [slc[0].shape[0] for slc in data]
    widths = [slc.shape[1] for slc in data[0]]
    fig_width = 12.0
    fig_height = fig_width * sum(heights) / sum(widths)
    f, axarr = plt.subplots(
        rows_data,
        columns_data,
        figsize=(fig_width, fig_height),
        gridspec_kw={"height_ratios": heights},
    )
    for i in range(rows_data):
        for j in range(columns_data):
            axarr[i, j].imshow(data[i][j], cmap="gray")
            axarr[i, j].axis("off")
    plt.subplots_adjust(wspace=0, hspace=0, left=0, right=1, bottom=0, top=1)
    plt.show()


# Visualize montage of slices.
# 4 rows and 10 columns for 100 slices of the CT scan.
plot_slices(4, 10, 128, 128, image[:, :, :40])
# Out:
# Dimension of the CT scan is: (128, 128, 64, 1)

# %%
# Compile model.
initial_learning_rate = 0.0001
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate, decay_steps=100000, decay_rate=0.96, staircase=True
)
model.compile(
    loss="binary_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=lr_schedule),
    metrics=["acc"],
)

# Define callbacks.
checkpoint_cb = keras.callbacks.ModelCheckpoint("iz_3_buffed_image.h5", save_best_only=True)
# early_stopping_cb = keras.callbacks.EarlyStopping(monitor="val_acc", patience=15)

# Train the model, doing validation at the end of each epoch
epochs = 100
model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=epochs,
    shuffle=True,
    verbose=2,
    callbacks=[
        checkpoint_cb,
    ],  # early_stopping_cb
)

print("End of Education")
# Out:
# Epoch 1/100
# 70/70 - 75s - loss: 0.6914 - acc: 0.5143 - val_loss: 0.7435 - val_acc: 0.5000 - 75s/epoch - 1s/step
# Epoch 2/100
# 70/70 - 67s - loss: 0.6725 - acc: 0.5500 - val_loss: 1.2080 - val_acc: 0.5000 - 67s/epoch - 961ms/step
# Epoch 3/100
# 70/70 - 54s - loss: 0.6601 - acc: 0.6357 - val_loss: 1.5957 - val_acc: 0.5000 - 54s/epoch - 767ms/step
# Epoch 4/100
# 70/70 - 64s - loss: 0.6732 - acc: 0.6000 - val_loss: 1.8285 - val_acc: 0.5000 - 64s/epoch - 918ms/step
# Epoch 5/100
# 70/70 - 37s - loss: 0.6229 - acc: 0.6714 - val_loss: 1.0379 - val_acc: 0.5000 - 37s/epoch - 533ms/step
# Epoch 6/100
# 70/70 - 25s - loss: 0.6236 - acc: 0.6643 - val_loss: 0.6951 - val_acc: 0.5167 - 25s/epoch - 351ms/step
# Epoch 7/100
# 70/70 - 36s - loss: 0.6368 - acc: 0.6286 - val_loss: 0.6900 - val_acc: 0.5000 - 36s/epoch - 513ms/step
# Epoch 8/100
# 70/70 - 35s - loss: 0.5730 - acc: 0.7000 - val_loss: 0.6410 - val_acc: 0.6500 - 35s/epoch - 506ms/step
# Epoch 9/100
# 70/70 - 51s - loss: 0.5847 - acc: 0.6857 - val_loss: 0.8453 - val_acc: 0.5167 - 51s/epoch - 727ms/step
# Epoch 10/100
# 70/70 - 84s - loss: 0.5888 - acc: 0.6643 - val_loss: 0.8137 - val_acc: 0.5833 - 84s/epoch - 1s/step
# Epoch 11/100
# 70/70 - 26s - loss: 0.5678 - acc: 0.6857 - val_loss: 0.6602 - val_acc: 0.7000 - 26s/epoch - 366ms/step
# Epoch 12/100
# 70/70 - 26s - loss: 0.5720 - acc: 0.7000 - val_loss: 0.6279 - val_acc: 0.6000 - 26s/epoch - 368ms/step
# Epoch 13/100
# 70/70 - 62s - loss: 0.5880 - acc: 0.6786 - val_loss: 0.6544 - val_acc: 0.6000 - 62s/epoch - 884ms/step
# Epoch 14/100
# 70/70 - 43s - loss: 0.5271 - acc: 0.7143 - val_loss: 0.6451 - val_acc: 0.6333 - 43s/epoch - 621ms/step
# Epoch 15/100
# 70/70 - 69s - loss: 0.5106 - acc: 0.7429 - val_loss: 0.6370 - val_acc: 0.7500 - 69s/epoch - 980ms/step
# Epoch 16/100
# 70/70 - 53s - loss: 0.5214 - acc: 0.7429 - val_loss: 0.5663 - val_acc: 0.6833 - 53s/epoch - 762ms/step
# Epoch 17/100
# 70/70 - 61s - loss: 0.4622 - acc: 0.7786 - val_loss: 1.0252 - val_acc: 0.5833 - 61s/epoch - 876ms/step
# Epoch 18/100
# 70/70 - 57s - loss: 0.5200 - acc: 0.7286 - val_loss: 0.6241 - val_acc: 0.6333 - 57s/epoch - 815ms/step
# Epoch 19/100
# 70/70 - 64s - loss: 0.5609 - acc: 0.6714 - val_loss: 0.5872 - val_acc: 0.7500 - 64s/epoch - 908ms/step
# Epoch 20/100
# 70/70 - 62s - loss: 0.5372 - acc: 0.7071 - val_loss: 0.6398 - val_acc: 0.6333 - 62s/epoch - 880ms/step
# Epoch 21/100
# 70/70 - 54s - loss: 0.5013 - acc: 0.7071 - val_loss: 0.6278 - val_acc: 0.6333 - 54s/epoch - 775ms/step
# Epoch 22/100
# 70/70 - 60s - loss: 0.4394 - acc: 0.7929 - val_loss: 0.7180 - val_acc: 0.6333 - 60s/epoch - 861ms/step
# Epoch 23/100
# 70/70 - 37s - loss: 0.5443 - acc: 0.7286 - val_loss: 0.9463 - val_acc: 0.5833 - 37s/epoch - 529ms/step
# Epoch 24/100
# 70/70 - 35s - loss: 0.4987 - acc: 0.7357 - val_loss: 0.5773 - val_acc: 0.6833 - 35s/epoch - 497ms/step
# Epoch 25/100
# 70/70 - 38s - loss: 0.4621 - acc: 0.8000 - val_loss: 0.5097 - val_acc: 0.7333 - 38s/epoch - 543ms/step
# Epoch 26/100
# 70/70 - 42s - loss: 0.4831 - acc: 0.7429 - val_loss: 0.5728 - val_acc: 0.6500 - 42s/epoch - 593ms/step
# Epoch 27/100
# 70/70 - 25s - loss: 0.4319 - acc: 0.7643 - val_loss: 0.6574 - val_acc: 0.6000 - 25s/epoch - 355ms/step
# Epoch 28/100
# 70/70 - 59s - loss: 0.4046 - acc: 0.8214 - val_loss: 1.3569 - val_acc: 0.5500 - 59s/epoch - 837ms/step
# Epoch 29/100
# 70/70 - 40s - loss: 0.4197 - acc: 0.8214 - val_loss: 2.2326 - val_acc: 0.5000 - 40s/epoch - 577ms/step
# Epoch 30/100
# 70/70 - 59s - loss: 0.4127 - acc: 0.7714 - val_loss: 1.4845 - val_acc: 0.5000 - 59s/epoch - 840ms/step
# Epoch 31/100
# 70/70 - 65s - loss: 0.4467 - acc: 0.7857 - val_loss: 0.7653 - val_acc: 0.7167 - 65s/epoch - 924ms/step
# Epoch 32/100
# 70/70 - 31s - loss: 0.4224 - acc: 0.8000 - val_loss: 0.9805 - val_acc: 0.5500 - 31s/epoch - 444ms/step
# Epoch 33/100
# 70/70 - 61s - loss: 0.4030 - acc: 0.8071 - val_loss: 0.6573 - val_acc: 0.6667 - 61s/epoch - 872ms/step
# Epoch 34/100
# 70/70 - 53s - loss: 0.3814 - acc: 0.8214 - val_loss: 0.7022 - val_acc: 0.6500 - 53s/epoch - 752ms/step
# Epoch 35/100
# 70/70 - 65s - loss: 0.3770 - acc: 0.8143 - val_loss: 0.6422 - val_acc: 0.6667 - 65s/epoch - 927ms/step
# Epoch 36/100
# 70/70 - 55s - loss: 0.3850 - acc: 0.8429 - val_loss: 1.4520 - val_acc: 0.5667 - 55s/epoch - 785ms/step
# Epoch 37/100
# 70/70 - 58s - loss: 0.3265 - acc: 0.8714 - val_loss: 0.5980 - val_acc: 0.6667 - 58s/epoch - 829ms/step
# Epoch 38/100
# 70/70 - 61s - loss: 0.3135 - acc: 0.8786 - val_loss: 0.8057 - val_acc: 0.6833 - 61s/epoch - 866ms/step
# Epoch 39/100
# 70/70 - 39s - loss: 0.3119 - acc: 0.8714 - val_loss: 0.7315 - val_acc: 0.6167 - 39s/epoch - 552ms/step
# Epoch 40/100
# 70/70 - 31s - loss: 0.3444 - acc: 0.8429 - val_loss: 0.7101 - val_acc: 0.6833 - 31s/epoch - 441ms/step
# Epoch 41/100
# 70/70 - 34s - loss: 0.4048 - acc: 0.8000 - val_loss: 0.6991 - val_acc: 0.7500 - 34s/epoch - 479ms/step
# Epoch 42/100
# 70/70 - 35s - loss: 0.4147 - acc: 0.7929 - val_loss: 1.0579 - val_acc: 0.6000 - 35s/epoch - 498ms/step
# Epoch 43/100
# 70/70 - 56s - loss: 0.2964 - acc: 0.8643 - val_loss: 0.8141 - val_acc: 0.6333 - 56s/epoch - 802ms/step
# Epoch 44/100
# 70/70 - 62s - loss: 0.2530 - acc: 0.9000 - val_loss: 0.7877 - val_acc: 0.6667 - 62s/epoch - 880ms/step
# Epoch 45/100
# 70/70 - 25s - loss: 0.2948 - acc: 0.8500 - val_loss: 1.0903 - val_acc: 0.6667 - 25s/epoch - 351ms/step
# Epoch 46/100
# 70/70 - 65s - loss: 0.3114 - acc: 0.8357 - val_loss: 1.3964 - val_acc: 0.5667 - 65s/epoch - 934ms/step
# Epoch 47/100
# 70/70 - 54s - loss: 0.3263 - acc: 0.8571 - val_loss: 1.2911 - val_acc: 0.5500 - 54s/epoch - 767ms/step
# Epoch 48/100
# 70/70 - 64s - loss: 0.2835 - acc: 0.8786 - val_loss: 1.0677 - val_acc: 0.5833 - 64s/epoch - 912ms/step
# Epoch 49/100
# 70/70 - 61s - loss: 0.2580 - acc: 0.9143 - val_loss: 3.3305 - val_acc: 0.5333 - 61s/epoch - 873ms/step
# Epoch 50/100
# 70/70 - 87s - loss: 0.2513 - acc: 0.9000 - val_loss: 0.9141 - val_acc: 0.6667 - 87s/epoch - 1s/step
# Epoch 51/100
# 70/70 - 64s - loss: 0.3046 - acc: 0.8357 - val_loss: 1.2189 - val_acc: 0.6333 - 64s/epoch - 912ms/step
# Epoch 52/100
# 70/70 - 67s - loss: 0.2749 - acc: 0.8786 - val_loss: 0.9807 - val_acc: 0.5833 - 67s/epoch - 958ms/step
# Epoch 53/100
# 70/70 - 60s - loss: 0.2945 - acc: 0.8500 - val_loss: 0.8142 - val_acc: 0.6833 - 60s/epoch - 862ms/step
# Epoch 54/100
# 70/70 - 71s - loss: 0.3099 - acc: 0.8643 - val_loss: 0.7528 - val_acc: 0.6667 - 71s/epoch - 1s/step
# Epoch 55/100
# 70/70 - 58s - loss: 0.2756 - acc: 0.9071 - val_loss: 0.7355 - val_acc: 0.6667 - 58s/epoch - 832ms/step
# Epoch 56/100
# 70/70 - 24s - loss: 0.2198 - acc: 0.9071 - val_loss: 0.8693 - val_acc: 0.6667 - 24s/epoch - 347ms/step
# Epoch 57/100
# 70/70 - 30s - loss: 0.2756 - acc: 0.8571 - val_loss: 0.6950 - val_acc: 0.6833 - 30s/epoch - 432ms/step
# Epoch 58/100
# 70/70 - 32s - loss: 0.2168 - acc: 0.9357 - val_loss: 0.7565 - val_acc: 0.7167 - 32s/epoch - 457ms/step
# Epoch 59/100
# 70/70 - 40s - loss: 0.1857 - acc: 0.9643 - val_loss: 2.6571 - val_acc: 0.5667 - 40s/epoch - 565ms/step
# Epoch 60/100
# 70/70 - 51s - loss: 0.2211 - acc: 0.9214 - val_loss: 0.8715 - val_acc: 0.6667 - 51s/epoch - 723ms/step
# Epoch 61/100
# 70/70 - 71s - loss: 0.2154 - acc: 0.9286 - val_loss: 1.0500 - val_acc: 0.7000 - 71s/epoch - 1s/step
# Epoch 62/100
# 70/70 - 74s - loss: 0.2582 - acc: 0.9000 - val_loss: 1.8240 - val_acc: 0.5833 - 74s/epoch - 1s/step
# Epoch 63/100
# 70/70 - 75s - loss: 0.1862 - acc: 0.9286 - val_loss: 0.8680 - val_acc: 0.6833 - 75s/epoch - 1s/step
# Epoch 64/100
# 70/70 - 63s - loss: 0.1906 - acc: 0.9143 - val_loss: 1.1191 - val_acc: 0.6833 - 63s/epoch - 898ms/step
# Epoch 65/100
# 70/70 - 57s - loss: 0.1813 - acc: 0.9429 - val_loss: 2.6894 - val_acc: 0.5000 - 57s/epoch - 821ms/step
# Epoch 66/100
# 70/70 - 25s - loss: 0.2253 - acc: 0.9071 - val_loss: 1.4097 - val_acc: 0.5833 - 25s/epoch - 352ms/step
# Epoch 67/100
# 70/70 - 46s - loss: 0.1505 - acc: 0.9500 - val_loss: 4.3590 - val_acc: 0.5500 - 46s/epoch - 654ms/step
# Epoch 68/100
# 70/70 - 62s - loss: 0.2164 - acc: 0.9000 - val_loss: 1.1573 - val_acc: 0.6667 - 62s/epoch - 884ms/step
# Epoch 69/100
# 70/70 - 59s - loss: 0.1716 - acc: 0.9500 - val_loss: 1.1758 - val_acc: 0.7000 - 59s/epoch - 836ms/step
# Epoch 70/100
# 70/70 - 72s - loss: 0.1887 - acc: 0.9357 - val_loss: 1.1916 - val_acc: 0.6500 - 72s/epoch - 1s/step
# Epoch 71/100
# 70/70 - 34s - loss: 0.1690 - acc: 0.9429 - val_loss: 0.9688 - val_acc: 0.7167 - 34s/epoch - 492ms/step
# Epoch 72/100
# 70/70 - 36s - loss: 0.1642 - acc: 0.9571 - val_loss: 1.9250 - val_acc: 0.5833 - 36s/epoch - 516ms/step
# Epoch 73/100
# 70/70 - 50s - loss: 0.1987 - acc: 0.9286 - val_loss: 0.9200 - val_acc: 0.6333 - 50s/epoch - 712ms/step
# Epoch 74/100
# 70/70 - 70s - loss: 0.1701 - acc: 0.9643 - val_loss: 0.9644 - val_acc: 0.6500 - 70s/epoch - 1s/step
# Epoch 75/100
# 70/70 - 75s - loss: 0.1621 - acc: 0.9500 - val_loss: 0.8223 - val_acc: 0.7333 - 75s/epoch - 1s/step
# Epoch 76/100
# 70/70 - 71s - loss: 0.1401 - acc: 0.9571 - val_loss: 1.0579 - val_acc: 0.6167 - 71s/epoch - 1s/step
# Epoch 77/100
# 70/70 - 54s - loss: 0.1634 - acc: 0.9357 - val_loss: 0.7739 - val_acc: 0.7167 - 54s/epoch - 769ms/step
# Epoch 78/100
# 70/70 - 31s - loss: 0.1776 - acc: 0.9357 - val_loss: 0.6635 - val_acc: 0.7833 - 31s/epoch - 447ms/step
# Epoch 79/100
# 70/70 - 63s - loss: 0.1120 - acc: 0.9786 - val_loss: 0.8665 - val_acc: 0.7333 - 63s/epoch - 896ms/step
# Epoch 80/100
# 70/70 - 57s - loss: 0.1590 - acc: 0.9286 - val_loss: 0.9797 - val_acc: 0.7167 - 57s/epoch - 810ms/step
# Epoch 81/100
# 70/70 - 63s - loss: 0.1304 - acc: 0.9571 - val_loss: 1.5771 - val_acc: 0.6000 - 63s/epoch - 903ms/step
# Epoch 82/100
# 70/70 - 55s - loss: 0.1259 - acc: 0.9643 - val_loss: 1.0983 - val_acc: 0.6833 - 55s/epoch - 785ms/step
# Epoch 83/100
# 70/70 - 32s - loss: 0.1246 - acc: 0.9429 - val_loss: 0.9262 - val_acc: 0.6500 - 32s/epoch - 459ms/step
# Epoch 84/100
# 70/70 - 52s - loss: 0.0909 - acc: 0.9714 - val_loss: 0.9240 - val_acc: 0.6833 - 52s/epoch - 746ms/step
# Epoch 85/100
# 70/70 - 40s - loss: 0.1340 - acc: 0.9500 - val_loss: 0.9479 - val_acc: 0.6833 - 40s/epoch - 572ms/step
# Epoch 86/100
# 70/70 - 25s - loss: 0.1200 - acc: 0.9357 - val_loss: 1.1681 - val_acc: 0.7000 - 25s/epoch - 356ms/step
# Epoch 87/100
# 70/70 - 51s - loss: 0.1339 - acc: 0.9643 - val_loss: 0.8910 - val_acc: 0.7167 - 51s/epoch - 728ms/step
# Epoch 88/100
# 70/70 - 58s - loss: 0.1162 - acc: 0.9571 - val_loss: 0.7546 - val_acc: 0.7333 - 58s/epoch - 824ms/step
# Epoch 89/100
# 70/70 - 69s - loss: 0.1245 - acc: 0.9500 - val_loss: 1.2291 - val_acc: 0.6667 - 69s/epoch - 988ms/step
# Epoch 90/100
# 70/70 - 52s - loss: 0.0961 - acc: 0.9714 - val_loss: 1.2507 - val_acc: 0.6000 - 52s/epoch - 741ms/step
# Epoch 91/100
# 70/70 - 58s - loss: 0.1362 - acc: 0.9429 - val_loss: 1.1311 - val_acc: 0.6667 - 58s/epoch - 834ms/step
# Epoch 92/100
# 70/70 - 65s - loss: 0.0772 - acc: 0.9786 - val_loss: 1.0829 - val_acc: 0.7000 - 65s/epoch - 923ms/step
# Epoch 93/100
# 70/70 - 53s - loss: 0.0686 - acc: 1.0000 - val_loss: 0.8962 - val_acc: 0.7333 - 53s/epoch - 757ms/step
# Epoch 94/100
# 70/70 - 70s - loss: 0.0721 - acc: 0.9786 - val_loss: 1.8337 - val_acc: 0.5833 - 70s/epoch - 1s/step
# Epoch 95/100
# 70/70 - 43s - loss: 0.0904 - acc: 0.9643 - val_loss: 0.8316 - val_acc: 0.7500 - 43s/epoch - 616ms/step
# Epoch 96/100
# 70/70 - 66s - loss: 0.0862 - acc: 0.9714 - val_loss: 0.9215 - val_acc: 0.7500 - 66s/epoch - 941ms/step
# Epoch 97/100
# 70/70 - 33s - loss: 0.0789 - acc: 0.9857 - val_loss: 2.7090 - val_acc: 0.5833 - 33s/epoch - 469ms/step
# Epoch 98/100
# 70/70 - 26s - loss: 0.1853 - acc: 0.9214 - val_loss: 1.3180 - val_acc: 0.7000 - 26s/epoch - 367ms/step
# Epoch 99/100
# 70/70 - 56s - loss: 0.1281 - acc: 0.9571 - val_loss: 0.8142 - val_acc: 0.7667 - 56s/epoch - 799ms/step
# Epoch 100/100
# 70/70 - 61s - loss: 0.0822 - acc: 0.9571 - val_loss: 0.8946 - val_acc: 0.6667 - 61s/epoch - 871ms/step
# End of Education

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 3))
ax = ax.ravel()

for i, metric in enumerate(["acc", "loss"]):
    ax[i].plot(model.history.history[metric])
    ax[i].plot(model.history.history["val_" + metric])
    ax[i].set_title("Model {}".format(metric))
    ax[i].set_xlabel("epochs")
    ax[i].set_ylabel(metric)
    ax[i].legend(["train", "val"])

# %%
# Load best weights.
model.load_weights("iz_3_buffed_image.h5")
prediction = model.predict(np.expand_dims(x_val[0], axis=0))[0]
scores = [1 - prediction[0], prediction[0]]

class_names = ["normal", "abnormal"]
for score, name in zip(scores, class_names):
    print(
        "This model is %.2f percent confident that CT scan is %s"
        % ((100 * score), name)
    )
    print("And this is " + str(y_val[0]))


datagen = ImageDataGenerator()
generator = datagen.flow(x_val, batch_size=batch_size, shuffle=False)

y_pred = model.predict_generator(generator, steps=np.ceil(len(x_val) / batch_size))


y_pred_binary = (y_pred > 0.5).astype(int)


# метрики
accuracy = accuracy_score(y_val, y_pred_binary)
precision = precision_score(y_val, y_pred_binary)
recall = recall_score(y_val, y_pred_binary)

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")


model.save("iz_3_buffed_image_save", save_format="tf")

plt.show()
# Out:
# 1/1 [==============================] - 1s 533ms/step
# This model is 25.51 percent confident that CT scan is normal
# And this is 1
# This model is 74.49 percent confident that CT scan is abnormal
# And this is 1
# c:\Develop\miniconda\envs\py310\lib\site-packages\keras_preprocessing\image\numpy_array_iterator.py:129: UserWarning: NumpyArrayIterator is set to use the data format convention "channels_last" (channels on axis 3), i.e. expected either 1, 3, or 4 channels on axis 3. However, it was passed an array with shape (60, 128, 128, 64) (64 channels).
#   warnings.warn('NumpyArrayIterator is set to use the '
# C:\Users\danek\AppData\Local\Temp\ipykernel_13212\213256542.py:29: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   y_pred = model.predict_generator(generator, steps=np.ceil(len(x_val) / batch_size))
# Accuracy: 0.7333333333333333
# Precision: 0.71875
# Recall: 0.7666666666666667
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: iz_3_image_save\assets
# INFO:tensorflow:Assets written to: iz_3_image_save\assets
