# %%
# !pip install keras_preprocessing

import os

os.environ["TF_GPU_ALLOCATOR"] = "cuda_malloc_async"

import pickle
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from sklearn.metrics import accuracy_score, precision_score, recall_score
from keras_preprocessing.image import ImageDataGenerator

from tensorflow import keras
from tensorflow.keras import layers

import nibabel as nib

from scipy import ndimage


def read_nifti_file(filepath):
    """Read and load volume"""
    # Read file
    scan = nib.load(filepath)
    # Get raw data
    scan = scan.get_fdata()
    return scan


def normalize(volume):
    """Normalize the volume"""
    min = -1000
    max = 400
    volume[volume < min] = min
    volume[volume > max] = max
    volume = (volume - min) / (max - min)
    volume = volume.astype("float32")
    return volume


def resize_volume(img):
    """Resize across z-axis"""
    # Set the desired depth
    desired_depth = 64
    desired_width = 128
    desired_height = 128
    # Get current depth
    current_depth = img.shape[-1]
    current_width = img.shape[0]
    current_height = img.shape[1]
    # Compute depth factor
    depth = current_depth / desired_depth
    width = current_width / desired_width
    height = current_height / desired_height
    depth_factor = 1 / depth
    width_factor = 1 / width
    height_factor = 1 / height
    # Rotate
    img = ndimage.rotate(img, 90, reshape=False)
    # Resize across z-axis
    img = ndimage.zoom(img, (width_factor, height_factor, depth_factor), order=1)
    return img


def process_scan(path):
    """Read and resize volume"""
    # Read scan
    volume = read_nifti_file(path)
    # Normalize
    volume = normalize(volume)
    # Resize width, height and depth
    volume = resize_volume(volume)
    return volume


# Тестим наличие видиокарты
from tensorflow.python.client import device_lib
import tensorflow as tf

gpus = tf.config.experimental.list_physical_devices("GPU")
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
            print(tf.config.experimental.get_memory_info("GPU:0")["current"])
        logical_gpus = tf.config.experimental.list_logical_devices("GPU")
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        print(e)
else:
    print('False')
# Out:
# Collecting keras_preprocessing
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.9.1 in /opt/conda/lib/python3.10/site-packages (from keras_preprocessing) (1.24.3)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/lib/python3.10/site-packages (from keras_preprocessing) (1.16.0)
# Installing collected packages: keras_preprocessing
# Successfully installed keras_preprocessing-1.1.2
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# 0
# 1 Physical GPUs, 1 Logical GPUs

# %%
# подготовка данных

# normal_scan_folder = "parsed_data/good"
# abnormal_scan_folder = "parsed_data/bad"
# # Folder "CT-0" consist of CT scans having normal lung tissue,
# # no CT-signs of viral pneumonia.
# normal_scan_paths = [
#     os.path.join(os.getcwd(), normal_scan_folder, x)
#     for x in os.listdir(normal_scan_folder)
# ]
# # Folder "CT-23" consist of CT scans having several ground-glass opacifications,
# # involvement of lung parenchyma.
# abnormal_scan_paths = [
#     os.path.join(os.getcwd(), abnormal_scan_folder, x)
#     for x in os.listdir(abnormal_scan_folder)
# ]

# print("CT scans with normal lung tissue: " + str(len(normal_scan_paths)))
# print("CT scans with abnormal lung tissue: " + str(len(abnormal_scan_paths)))

# normal_scan_paths = normal_scan_paths[:100]
# abnormal_scan_paths = abnormal_scan_paths[:100]

# # Read and process the scans.
# # Each scan is resized across height, width, and depth and rescaled.
# abnormal_scans = np.array([process_scan(path) for path in abnormal_scan_paths])
# normal_scans = np.array([process_scan(path) for path in normal_scan_paths])

# state_to_save = {
#     'abnormal_scans': abnormal_scans,
#     'normal_scans': normal_scans,
# }

# with open('200saved_state333.pickle', 'wb') as file:
#     pickle.dump(state_to_save, file)

# %%
with open('/kaggle/input/iz-3-data/200saved_state333.pickle', 'rb') as file:
    loaded_state = pickle.load(file)

abnormal_scans = loaded_state['abnormal_scans']
normal_scans = loaded_state['normal_scans']

# For the CT scans having presence of viral pneumonia
# assign 1, for the normal ones assign 0.
abnormal_labels = np.array([1 for _ in range(len(abnormal_scans))])
normal_labels = np.array([0 for _ in range(len(normal_scans))])

# Split data in the ratio 70-30 for training and validation.
x_train = np.concatenate((abnormal_scans[:70], normal_scans[:70]), axis=0)
y_train = np.concatenate((abnormal_labels[:70], normal_labels[:70]), axis=0)
x_val = np.concatenate((abnormal_scans[70:], normal_scans[70:]), axis=0)
y_val = np.concatenate((abnormal_labels[70:], normal_labels[70:]), axis=0)
print(
    "Number of samples in train and validation are %d and %d."
    % (x_train.shape[0], x_val.shape[0])
)
# Out:
# Number of samples in train and validation are 140 and 60.

# %%
import random
from scipy import ndimage


@tf.function
def rotate(volume):
    """Rotate the volume by a few degrees"""

    def scipy_rotate(volume):
        # define some rotation angles
        angles = [-20, -10, -5, 5, 10, 20]
        # pick angles at random
        angle = random.choice(angles)
        # rotate volume
        volume = ndimage.rotate(volume, angle, reshape=False)
        volume[volume < 0] = 0
        volume[volume > 1] = 1
        return volume

    augmented_volume = tf.numpy_function(scipy_rotate, [volume], tf.float32)
    return augmented_volume


def train_preprocessing(volume, label):
    """Process training data by rotating and adding a channel."""
    # Rotate volume
    volume = rotate(volume)
    volume = tf.expand_dims(volume, axis=3)
    return volume, label


def validation_preprocessing(volume, label):
    """Process validation data by only adding a channel."""
    volume = tf.expand_dims(volume, axis=3)
    return volume, label


# print(tf.config.experimental.get_memory_info("GPU:0")["current"])
# Define data loaders.
train_loader = tf.data.Dataset.from_tensor_slices((x_train, y_train))
validation_loader = tf.data.Dataset.from_tensor_slices((x_val, y_val))


batch_size = 4
# Augment the on the fly during training.
train_dataset = (
    train_loader.shuffle(len(x_train))
    .map(train_preprocessing)
    .batch(batch_size)
    .prefetch(2)
)
# Only rescale.
validation_dataset = (
    validation_loader.shuffle(len(x_val))
    .map(validation_preprocessing)
    .batch(batch_size)
    .prefetch(2)
)

def get_model(width=128, height=128, depth=64):
    """Build a 3D convolutional neural network model."""

    inputs = keras.Input((width, height, depth, 1))

    x = layers.Conv3D(filters=64, kernel_size=3, activation="relu")(inputs)
    x = layers.MaxPool3D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)

    x = layers.Conv3D(filters=64, kernel_size=3, activation="relu")(x)
    x = layers.MaxPool3D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)

    x = layers.Conv3D(filters=128, kernel_size=3, activation="relu")(x)
    x = layers.MaxPool3D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)

    x = layers.Conv3D(filters=256, kernel_size=3, activation="relu")(x)
    x = layers.MaxPool3D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)

    x = layers.GlobalAveragePooling3D()(x)
    x = layers.Dense(units=512, activation="relu")(x)
    x = layers.Dropout(0.3)(x)

    outputs = layers.Dense(units=1, activation="sigmoid")(x)

    # Define the model.
    model = keras.Model(inputs, outputs, name="3dcnn")
    return model


# Build model.
model = get_model(width=128, height=128, depth=64)
model.summary()
# Out:
# Model: "3dcnn"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 64, 1   0
#                              )]
#
#  conv3d (Conv3D)             (None, 126, 126, 62, 64   1792
#                              )
#
#  max_pooling3d (MaxPooling3  (None, 63, 63, 31, 64)    0
#  D)
#
#  batch_normalization (Batch  (None, 63, 63, 31, 64)    256
#  Normalization)
#
#  conv3d_1 (Conv3D)           (None, 61, 61, 29, 64)    110656
#
#  max_pooling3d_1 (MaxPoolin  (None, 30, 30, 14, 64)    0
#  g3D)
#
#  batch_normalization_1 (Bat  (None, 30, 30, 14, 64)    256
#  chNormalization)
#
#  conv3d_2 (Conv3D)           (None, 28, 28, 12, 128)   221312
#
#  max_pooling3d_2 (MaxPoolin  (None, 14, 14, 6, 128)    0
#  g3D)
#
#  batch_normalization_2 (Bat  (None, 14, 14, 6, 128)    512
#  chNormalization)
#
#  conv3d_3 (Conv3D)           (None, 12, 12, 4, 256)    884992
#
#  max_pooling3d_3 (MaxPoolin  (None, 6, 6, 2, 256)      0
#  g3D)
#
#  batch_normalization_3 (Bat  (None, 6, 6, 2, 256)      1024
#  chNormalization)
#
#  global_average_pooling3d (  (None, 256)               0
#  GlobalAveragePooling3D)
#
#  dense (Dense)               (None, 512)               131584
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 1352897 (5.16 MB)
# Trainable params: 1351873 (5.16 MB)
# Non-trainable params: 1024 (4.00 KB)
# _________________________________________________________________

# %%
# Показ снимков
data = train_dataset.take(1)
images, labels = list(data)[0]
images = images.numpy()
image = images[0]
print("Dimension of the CT scan is:", image.shape)
plt.imshow(np.squeeze(image[:, :, 30]), cmap="gray")

def plot_slices(num_rows, num_columns, width, height, data):
    """Plot a montage of 20 CT slices"""
    data = np.rot90(np.array(data))
    data = np.transpose(data)
    data = np.reshape(data, (num_rows, num_columns, width, height))
    rows_data, columns_data = data.shape[0], data.shape[1]
    heights = [slc[0].shape[0] for slc in data]
    widths = [slc.shape[1] for slc in data[0]]
    fig_width = 12.0
    fig_height = fig_width * sum(heights) / sum(widths)
    f, axarr = plt.subplots(
        rows_data,
        columns_data,
        figsize=(fig_width, fig_height),
        gridspec_kw={"height_ratios": heights},
    )
    for i in range(rows_data):
        for j in range(columns_data):
            axarr[i, j].imshow(data[i][j], cmap="gray")
            axarr[i, j].axis("off")
    plt.subplots_adjust(wspace=0, hspace=0, left=0, right=1, bottom=0, top=1)
    plt.show()


# Visualize montage of slices.
# 4 rows and 10 columns for 100 slices of the CT scan.
plot_slices(4, 10, 128, 128, image[:, :, :40])
# Out:
# Dimension of the CT scan is: (128, 128, 64, 1)

# %%
# Compile model.
initial_learning_rate = 0.0001
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate, decay_steps=100000, decay_rate=0.96, staircase=True
)
model.compile(
    loss="binary_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=lr_schedule),
    metrics=["acc"],
)

# Define callbacks.
checkpoint_cb = keras.callbacks.ModelCheckpoint("iz_3_buffed_image.h5", save_best_only=True)
# early_stopping_cb = keras.callbacks.EarlyStopping(monitor="val_acc", patience=15)

# Train the model, doing validation at the end of each epoch
epochs = 100
model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=epochs,
    shuffle=True,
    verbose=2,
    callbacks=[
        checkpoint_cb,
    ],  # early_stopping_cb
)

print("End of Education")
# Out:
# Epoch 1/100
# 35/35 - 32s - loss: 0.6804 - acc: 0.5714 - val_loss: 0.6937 - val_acc: 0.5000 - 32s/epoch - 920ms/step
# Epoch 2/100
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 35/35 - 21s - loss: 0.6774 - acc: 0.5786 - val_loss: 0.7321 - val_acc: 0.5000 - 21s/epoch - 599ms/step
# Epoch 3/100
# 35/35 - 21s - loss: 0.6078 - acc: 0.6929 - val_loss: 0.8539 - val_acc: 0.5000 - 21s/epoch - 596ms/step
# Epoch 4/100
# 35/35 - 21s - loss: 0.5770 - acc: 0.7214 - val_loss: 1.0141 - val_acc: 0.5000 - 21s/epoch - 598ms/step
# Epoch 5/100
# 35/35 - 21s - loss: 0.5731 - acc: 0.6714 - val_loss: 0.9847 - val_acc: 0.5000 - 21s/epoch - 598ms/step
# Epoch 6/100
# 35/35 - 21s - loss: 0.5367 - acc: 0.7214 - val_loss: 1.2140 - val_acc: 0.5000 - 21s/epoch - 598ms/step
# Epoch 7/100
# 35/35 - 21s - loss: 0.4996 - acc: 0.7929 - val_loss: 1.1678 - val_acc: 0.5000 - 21s/epoch - 604ms/step
# Epoch 8/100
# 35/35 - 21s - loss: 0.4741 - acc: 0.7786 - val_loss: 0.9347 - val_acc: 0.5000 - 21s/epoch - 597ms/step
# Epoch 9/100
# 35/35 - 21s - loss: 0.5014 - acc: 0.7786 - val_loss: 1.2697 - val_acc: 0.5000 - 21s/epoch - 595ms/step
# Epoch 10/100
# 35/35 - 21s - loss: 0.4917 - acc: 0.7286 - val_loss: 1.0114 - val_acc: 0.5000 - 21s/epoch - 596ms/step
# Epoch 11/100
# 35/35 - 21s - loss: 0.4643 - acc: 0.7571 - val_loss: 1.1631 - val_acc: 0.5000 - 21s/epoch - 599ms/step
# Epoch 12/100
# 35/35 - 21s - loss: 0.4235 - acc: 0.8143 - val_loss: 0.6620 - val_acc: 0.5167 - 21s/epoch - 598ms/step
# Epoch 13/100
# 35/35 - 21s - loss: 0.4906 - acc: 0.7143 - val_loss: 0.6031 - val_acc: 0.6833 - 21s/epoch - 600ms/step
# Epoch 14/100
# 35/35 - 21s - loss: 0.4090 - acc: 0.8071 - val_loss: 0.6751 - val_acc: 0.6167 - 21s/epoch - 598ms/step
# Epoch 15/100
# 35/35 - 21s - loss: 0.4455 - acc: 0.8143 - val_loss: 0.6227 - val_acc: 0.6833 - 21s/epoch - 599ms/step
# Epoch 16/100
# 35/35 - 21s - loss: 0.3898 - acc: 0.8071 - val_loss: 0.5509 - val_acc: 0.6667 - 21s/epoch - 596ms/step
# Epoch 17/100
# 35/35 - 21s - loss: 0.3299 - acc: 0.8786 - val_loss: 0.7036 - val_acc: 0.6667 - 21s/epoch - 593ms/step
# Epoch 18/100
# 35/35 - 21s - loss: 0.2948 - acc: 0.8857 - val_loss: 0.7614 - val_acc: 0.6167 - 21s/epoch - 599ms/step
# Epoch 19/100
# 35/35 - 21s - loss: 0.3356 - acc: 0.8786 - val_loss: 0.6877 - val_acc: 0.6000 - 21s/epoch - 595ms/step
# Epoch 20/100
# 35/35 - 21s - loss: 0.3332 - acc: 0.8429 - val_loss: 0.9175 - val_acc: 0.5667 - 21s/epoch - 598ms/step
# Epoch 21/100
# 35/35 - 21s - loss: 0.3123 - acc: 0.9000 - val_loss: 3.3039 - val_acc: 0.5000 - 21s/epoch - 599ms/step
# Epoch 22/100
# 35/35 - 21s - loss: 0.4443 - acc: 0.7857 - val_loss: 0.7645 - val_acc: 0.6167 - 21s/epoch - 596ms/step
# Epoch 23/100
# 35/35 - 21s - loss: 0.3051 - acc: 0.8786 - val_loss: 0.7044 - val_acc: 0.6167 - 21s/epoch - 598ms/step
# Epoch 24/100
# 35/35 - 21s - loss: 0.2844 - acc: 0.8857 - val_loss: 0.6976 - val_acc: 0.6667 - 21s/epoch - 598ms/step
# Epoch 25/100
# 35/35 - 21s - loss: 0.3060 - acc: 0.8786 - val_loss: 0.6679 - val_acc: 0.6667 - 21s/epoch - 590ms/step
# Epoch 26/100
# 35/35 - 21s - loss: 0.2707 - acc: 0.8857 - val_loss: 0.9242 - val_acc: 0.6500 - 21s/epoch - 597ms/step
# Epoch 27/100
# 35/35 - 21s - loss: 0.3314 - acc: 0.8571 - val_loss: 1.7817 - val_acc: 0.5500 - 21s/epoch - 600ms/step
# Epoch 28/100
# 35/35 - 21s - loss: 0.2568 - acc: 0.9143 - val_loss: 0.9291 - val_acc: 0.6333 - 21s/epoch - 598ms/step
# Epoch 29/100
# 35/35 - 21s - loss: 0.2491 - acc: 0.9286 - val_loss: 0.6858 - val_acc: 0.6333 - 21s/epoch - 599ms/step
# Epoch 30/100
# 35/35 - 21s - loss: 0.2073 - acc: 0.9429 - val_loss: 2.0583 - val_acc: 0.5167 - 21s/epoch - 602ms/step
# Epoch 31/100
# 35/35 - 21s - loss: 0.2328 - acc: 0.9143 - val_loss: 1.1239 - val_acc: 0.5833 - 21s/epoch - 594ms/step
# Epoch 32/100
# 35/35 - 21s - loss: 0.1379 - acc: 0.9714 - val_loss: 0.8136 - val_acc: 0.6500 - 21s/epoch - 597ms/step
# Epoch 33/100
# 35/35 - 22s - loss: 0.1566 - acc: 0.9571 - val_loss: 1.3329 - val_acc: 0.5833 - 22s/epoch - 616ms/step
# Epoch 34/100
# 35/35 - 21s - loss: 0.1304 - acc: 0.9786 - val_loss: 0.6924 - val_acc: 0.6667 - 21s/epoch - 593ms/step
# Epoch 35/100
# 35/35 - 21s - loss: 0.2286 - acc: 0.9071 - val_loss: 1.0153 - val_acc: 0.6000 - 21s/epoch - 602ms/step
# Epoch 36/100
# 35/35 - 21s - loss: 0.1988 - acc: 0.9214 - val_loss: 0.9685 - val_acc: 0.5667 - 21s/epoch - 599ms/step
# Epoch 37/100
# 35/35 - 21s - loss: 0.2131 - acc: 0.9143 - val_loss: 1.2563 - val_acc: 0.6833 - 21s/epoch - 601ms/step
# Epoch 38/100
# 35/35 - 21s - loss: 0.1341 - acc: 0.9714 - val_loss: 1.4974 - val_acc: 0.5500 - 21s/epoch - 610ms/step
# Epoch 39/100
# 35/35 - 21s - loss: 0.1532 - acc: 0.9571 - val_loss: 0.6630 - val_acc: 0.6667 - 21s/epoch - 606ms/step
# Epoch 40/100
# 35/35 - 21s - loss: 0.1547 - acc: 0.9357 - val_loss: 4.7708 - val_acc: 0.5000 - 21s/epoch - 597ms/step
# Epoch 41/100
# 35/35 - 21s - loss: 0.2019 - acc: 0.9286 - val_loss: 0.9135 - val_acc: 0.5833 - 21s/epoch - 605ms/step
# Epoch 42/100
# 35/35 - 21s - loss: 0.1421 - acc: 0.9643 - val_loss: 4.1782 - val_acc: 0.5000 - 21s/epoch - 603ms/step
# Epoch 43/100
# 35/35 - 21s - loss: 0.1798 - acc: 0.9357 - val_loss: 3.7274 - val_acc: 0.5167 - 21s/epoch - 602ms/step
# Epoch 44/100
# 35/35 - 21s - loss: 0.0959 - acc: 0.9786 - val_loss: 1.6373 - val_acc: 0.5500 - 21s/epoch - 602ms/step
# Epoch 45/100
# 35/35 - 21s - loss: 0.1626 - acc: 0.9429 - val_loss: 1.6287 - val_acc: 0.6000 - 21s/epoch - 609ms/step
# Epoch 46/100
# 35/35 - 21s - loss: 0.1335 - acc: 0.9429 - val_loss: 0.8307 - val_acc: 0.7167 - 21s/epoch - 602ms/step
# Epoch 47/100
# 35/35 - 21s - loss: 0.1295 - acc: 0.9643 - val_loss: 2.2978 - val_acc: 0.5667 - 21s/epoch - 601ms/step
# Epoch 48/100
# 35/35 - 21s - loss: 0.1442 - acc: 0.9357 - val_loss: 0.7066 - val_acc: 0.7000 - 21s/epoch - 605ms/step
# Epoch 49/100
# 35/35 - 21s - loss: 0.1523 - acc: 0.9286 - val_loss: 0.8646 - val_acc: 0.6833 - 21s/epoch - 605ms/step
# Epoch 50/100
# 35/35 - 21s - loss: 0.1189 - acc: 0.9357 - val_loss: 1.0634 - val_acc: 0.6333 - 21s/epoch - 605ms/step
# Epoch 51/100
# 35/35 - 21s - loss: 0.0939 - acc: 0.9786 - val_loss: 1.4017 - val_acc: 0.6333 - 21s/epoch - 603ms/step
# Epoch 52/100
# 35/35 - 21s - loss: 0.1283 - acc: 0.9643 - val_loss: 2.3413 - val_acc: 0.5333 - 21s/epoch - 603ms/step
# Epoch 53/100
# 35/35 - 21s - loss: 0.1114 - acc: 0.9643 - val_loss: 1.3152 - val_acc: 0.6500 - 21s/epoch - 605ms/step
# Epoch 54/100
# 35/35 - 21s - loss: 0.0869 - acc: 0.9786 - val_loss: 1.4047 - val_acc: 0.6833 - 21s/epoch - 610ms/step
# Epoch 55/100
# 35/35 - 21s - loss: 0.0955 - acc: 0.9571 - val_loss: 4.9928 - val_acc: 0.5000 - 21s/epoch - 601ms/step
# Epoch 56/100
# 35/35 - 21s - loss: 0.2008 - acc: 0.9286 - val_loss: 1.7234 - val_acc: 0.5500 - 21s/epoch - 604ms/step
# Epoch 57/100
# 35/35 - 21s - loss: 0.1747 - acc: 0.9071 - val_loss: 1.1132 - val_acc: 0.5333 - 21s/epoch - 613ms/step
# Epoch 58/100
# 35/35 - 21s - loss: 0.1108 - acc: 0.9714 - val_loss: 0.8004 - val_acc: 0.7000 - 21s/epoch - 604ms/step
# Epoch 59/100
# 35/35 - 21s - loss: 0.1418 - acc: 0.9571 - val_loss: 0.9856 - val_acc: 0.6833 - 21s/epoch - 598ms/step
# Epoch 60/100
# 35/35 - 21s - loss: 0.1658 - acc: 0.9286 - val_loss: 1.2152 - val_acc: 0.6000 - 21s/epoch - 603ms/step
# Epoch 61/100
# 35/35 - 21s - loss: 0.0819 - acc: 0.9857 - val_loss: 0.9491 - val_acc: 0.6833 - 21s/epoch - 606ms/step
# Epoch 62/100
# 35/35 - 21s - loss: 0.0743 - acc: 0.9857 - val_loss: 0.8767 - val_acc: 0.6500 - 21s/epoch - 601ms/step
# Epoch 63/100
# 35/35 - 21s - loss: 0.0981 - acc: 0.9786 - val_loss: 2.8056 - val_acc: 0.5000 - 21s/epoch - 601ms/step
# Epoch 64/100
# 35/35 - 21s - loss: 0.1336 - acc: 0.9357 - val_loss: 1.4688 - val_acc: 0.6167 - 21s/epoch - 605ms/step
# Epoch 65/100
# 35/35 - 21s - loss: 0.0870 - acc: 0.9714 - val_loss: 1.8729 - val_acc: 0.5500 - 21s/epoch - 605ms/step
# Epoch 66/100
# 35/35 - 21s - loss: 0.1065 - acc: 0.9786 - val_loss: 2.3097 - val_acc: 0.5667 - 21s/epoch - 602ms/step
# Epoch 67/100
# 35/35 - 21s - loss: 0.0767 - acc: 0.9643 - val_loss: 1.2334 - val_acc: 0.6167 - 21s/epoch - 604ms/step
# Epoch 68/100
# 35/35 - 21s - loss: 0.1836 - acc: 0.9071 - val_loss: 4.0866 - val_acc: 0.5000 - 21s/epoch - 605ms/step
# Epoch 69/100
# 35/35 - 21s - loss: 0.1567 - acc: 0.9214 - val_loss: 1.1867 - val_acc: 0.6667 - 21s/epoch - 606ms/step
# Epoch 70/100
# 35/35 - 21s - loss: 0.0914 - acc: 0.9500 - val_loss: 1.3845 - val_acc: 0.6500 - 21s/epoch - 606ms/step
# Epoch 71/100
# 35/35 - 21s - loss: 0.1693 - acc: 0.9071 - val_loss: 1.2795 - val_acc: 0.6667 - 21s/epoch - 603ms/step
# Epoch 72/100
# 35/35 - 21s - loss: 0.0688 - acc: 0.9786 - val_loss: 1.1964 - val_acc: 0.6833 - 21s/epoch - 612ms/step
# Epoch 73/100
# 35/35 - 21s - loss: 0.0680 - acc: 0.9857 - val_loss: 4.8568 - val_acc: 0.5000 - 21s/epoch - 602ms/step
# Epoch 74/100
# 35/35 - 21s - loss: 0.0448 - acc: 0.9857 - val_loss: 1.3385 - val_acc: 0.6500 - 21s/epoch - 606ms/step
# Epoch 75/100
# 35/35 - 21s - loss: 0.0974 - acc: 0.9571 - val_loss: 3.1738 - val_acc: 0.5167 - 21s/epoch - 606ms/step
# Epoch 76/100
# 35/35 - 21s - loss: 0.1213 - acc: 0.9571 - val_loss: 1.1342 - val_acc: 0.6833 - 21s/epoch - 604ms/step
# Epoch 77/100
# 35/35 - 21s - loss: 0.0659 - acc: 0.9714 - val_loss: 1.4514 - val_acc: 0.6500 - 21s/epoch - 599ms/step
# Epoch 78/100
# 35/35 - 21s - loss: 0.0920 - acc: 0.9786 - val_loss: 1.3730 - val_acc: 0.6833 - 21s/epoch - 603ms/step
# Epoch 79/100
# 35/35 - 21s - loss: 0.0536 - acc: 0.9929 - val_loss: 1.2454 - val_acc: 0.6167 - 21s/epoch - 603ms/step
# Epoch 80/100
# 35/35 - 21s - loss: 0.0584 - acc: 1.0000 - val_loss: 0.9129 - val_acc: 0.6667 - 21s/epoch - 605ms/step
# Epoch 81/100
# 35/35 - 21s - loss: 0.0528 - acc: 0.9929 - val_loss: 1.9899 - val_acc: 0.5667 - 21s/epoch - 604ms/step
# Epoch 82/100
# 35/35 - 21s - loss: 0.1265 - acc: 0.9429 - val_loss: 1.0728 - val_acc: 0.6833 - 21s/epoch - 604ms/step
# Epoch 83/100
# 35/35 - 21s - loss: 0.0753 - acc: 0.9786 - val_loss: 2.1304 - val_acc: 0.5833 - 21s/epoch - 601ms/step
# Epoch 84/100
# 35/35 - 21s - loss: 0.0466 - acc: 0.9929 - val_loss: 1.0107 - val_acc: 0.6833 - 21s/epoch - 609ms/step
# Epoch 85/100
# 35/35 - 21s - loss: 0.0265 - acc: 0.9929 - val_loss: 1.8679 - val_acc: 0.6000 - 21s/epoch - 606ms/step
# Epoch 86/100
# 35/35 - 21s - loss: 0.0629 - acc: 0.9714 - val_loss: 1.3554 - val_acc: 0.6833 - 21s/epoch - 603ms/step
# Epoch 87/100
# 35/35 - 21s - loss: 0.0378 - acc: 0.9929 - val_loss: 1.0776 - val_acc: 0.6333 - 21s/epoch - 606ms/step
# Epoch 88/100
# 35/35 - 21s - loss: 0.0671 - acc: 0.9643 - val_loss: 0.9877 - val_acc: 0.7000 - 21s/epoch - 609ms/step
# Epoch 89/100
# 35/35 - 21s - loss: 0.0661 - acc: 0.9786 - val_loss: 1.0926 - val_acc: 0.7000 - 21s/epoch - 601ms/step
# Epoch 90/100
# 35/35 - 21s - loss: 0.0791 - acc: 0.9714 - val_loss: 1.2635 - val_acc: 0.6500 - 21s/epoch - 600ms/step
# Epoch 91/100
# 35/35 - 21s - loss: 0.0730 - acc: 0.9714 - val_loss: 2.1606 - val_acc: 0.5833 - 21s/epoch - 601ms/step
# Epoch 92/100
# 35/35 - 21s - loss: 0.0719 - acc: 0.9643 - val_loss: 1.0699 - val_acc: 0.6667 - 21s/epoch - 597ms/step
# Epoch 93/100
# 35/35 - 21s - loss: 0.1539 - acc: 0.9286 - val_loss: 1.8323 - val_acc: 0.5833 - 21s/epoch - 599ms/step
# Epoch 94/100
# 35/35 - 21s - loss: 0.0867 - acc: 0.9714 - val_loss: 1.3462 - val_acc: 0.6667 - 21s/epoch - 599ms/step
# Epoch 95/100
# 35/35 - 21s - loss: 0.0688 - acc: 0.9786 - val_loss: 2.7986 - val_acc: 0.5000 - 21s/epoch - 597ms/step
# Epoch 96/100
# 35/35 - 21s - loss: 0.0357 - acc: 1.0000 - val_loss: 1.1981 - val_acc: 0.5833 - 21s/epoch - 596ms/step
# Epoch 97/100
# 35/35 - 21s - loss: 0.0598 - acc: 0.9786 - val_loss: 1.1185 - val_acc: 0.6833 - 21s/epoch - 594ms/step
# Epoch 98/100
# 35/35 - 21s - loss: 0.0515 - acc: 0.9857 - val_loss: 2.2598 - val_acc: 0.5500 - 21s/epoch - 600ms/step
# Epoch 99/100
# 35/35 - 21s - loss: 0.0585 - acc: 0.9714 - val_loss: 1.2808 - val_acc: 0.6333 - 21s/epoch - 597ms/step
# Epoch 100/100
# 35/35 - 21s - loss: 0.0837 - acc: 0.9714 - val_loss: 1.2776 - val_acc: 0.6333 - 21s/epoch - 603ms/step
# End of Education

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 3))
ax = ax.ravel()

for i, metric in enumerate(["acc", "loss"]):
    ax[i].plot(model.history.history[metric])
    ax[i].plot(model.history.history["val_" + metric])
    ax[i].set_title("Model {}".format(metric))
    ax[i].set_xlabel("epochs")
    ax[i].set_ylabel(metric)
    ax[i].legend(["train", "val"])

# %%
# Load best weights.
model.load_weights("iz_3_buffed_image.h5")
prediction = model.predict(np.expand_dims(x_val[0], axis=0))[0]
scores = [1 - prediction[0], prediction[0]]

class_names = ["normal", "abnormal"]
for score, name in zip(scores, class_names):
    print(
        "This model is %.2f percent confident that CT scan is %s"
        % ((100 * score), name)
    )
    print("And this is " + str(y_val[0]))


datagen = ImageDataGenerator()
generator = datagen.flow(x_val, batch_size=batch_size, shuffle=False)

y_pred = model.predict_generator(generator, steps=np.ceil(len(x_val) / batch_size))


y_pred_binary = (y_pred > 0.5).astype(int)


# метрики
accuracy = accuracy_score(y_val, y_pred_binary)
precision = precision_score(y_val, y_pred_binary)
recall = recall_score(y_val, y_pred_binary)

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")


model.save("iz_3_buffed_image_save", save_format="tf")

plt.show()
# Out:
# 1/1 [==============================] - 0s 309ms/step
# This model is 30.43 percent confident that CT scan is normal
# And this is 1
# This model is 69.57 percent confident that CT scan is abnormal
# And this is 1
# /opt/conda/lib/python3.10/site-packages/keras_preprocessing/image/numpy_array_iterator.py:129: UserWarning: NumpyArrayIterator is set to use the data format convention "channels_last" (channels on axis 3), i.e. expected either 1, 3, or 4 channels on axis 3. However, it was passed an array with shape (60, 128, 128, 64) (64 channels).
#   warnings.warn('NumpyArrayIterator is set to use the '
# /tmp/ipykernel_42/1300884810.py:18: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   y_pred = model.predict_generator(generator, steps=np.ceil(len(x_val) / batch_size))
# Accuracy: 0.6666666666666666
# Precision: 0.7083333333333334
# Recall: 0.5666666666666667
