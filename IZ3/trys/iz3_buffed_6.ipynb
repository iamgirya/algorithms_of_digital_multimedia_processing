# %%
import os

os.environ["TF_GPU_ALLOCATOR"] = "cuda_malloc_async"

import pickle
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from sklearn.metrics import accuracy_score, precision_score, recall_score
from keras_preprocessing.image import ImageDataGenerator

from tensorflow import keras
from tensorflow.keras import layers

import nibabel as nib

from scipy import ndimage

try_name = 'iz3_buffed_6'

def read_nifti_file(filepath):
    """Read and load volume"""
    # Read file
    scan = nib.load(filepath)
    # Get raw data
    scan = scan.get_fdata()
    return scan


def normalize(volume):
    """Normalize the volume"""
    min = -1000
    max = 400
    volume[volume < min] = min
    volume[volume > max] = max
    volume = (volume - min) / (max - min)
    volume = volume.astype("float32")
    return volume


def resize_volume(img):
    """Resize across z-axis"""
    # Set the desired depth
    desired_depth = 64
    desired_width = 128
    desired_height = 128
    # Get current depth
    current_depth = img.shape[-1]
    current_width = img.shape[0]
    current_height = img.shape[1]
    # Compute depth factor
    depth = current_depth / desired_depth
    width = current_width / desired_width
    height = current_height / desired_height
    depth_factor = 1 / depth
    width_factor = 1 / width
    height_factor = 1 / height
    # Rotate
    img = ndimage.rotate(img, 90, reshape=False)
    # Resize across z-axis
    img = ndimage.zoom(img, (width_factor, height_factor, depth_factor), order=1)
    return img


def process_scan(path):
    """Read and resize volume"""
    # Read scan
    volume = read_nifti_file(path)
    # Normalize
    volume = normalize(volume)
    # Resize width, height and depth
    volume = resize_volume(volume)
    return volume


# Тестим наличие видиокарты
from tensorflow.python.client import device_lib
import tensorflow as tf

gpus = tf.config.experimental.list_physical_devices("GPU")
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
            print(tf.config.experimental.get_memory_info("GPU:0")["current"])
        logical_gpus = tf.config.experimental.list_logical_devices("GPU")
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        print(e)
# Out:
# 0
# 1 Physical GPUs, 1 Logical GPUs

# %%
# подготовка данных

# normal_scan_folder = "parsed_data/good"
# abnormal_scan_folder = "parsed_data/bad"
# # Folder "CT-0" consist of CT scans having normal lung tissue,
# # no CT-signs of viral pneumonia.
# normal_scan_paths = [
#     os.path.join(os.getcwd(), normal_scan_folder, x)
#     for x in os.listdir(normal_scan_folder)
# ]
# # Folder "CT-23" consist of CT scans having several ground-glass opacifications,
# # involvement of lung parenchyma.
# abnormal_scan_paths = [
#     os.path.join(os.getcwd(), abnormal_scan_folder, x)
#     for x in os.listdir(abnormal_scan_folder)
# ]

# print("CT scans with normal lung tissue: " + str(len(normal_scan_paths)))
# print("CT scans with abnormal lung tissue: " + str(len(abnormal_scan_paths)))

# normal_scan_paths = normal_scan_paths[:100]
# abnormal_scan_paths = abnormal_scan_paths[:100]

# # Read and process the scans.
# # Each scan is resized across height, width, and depth and rescaled.
# abnormal_scans = np.array([process_scan(path) for path in abnormal_scan_paths])
# normal_scans = np.array([process_scan(path) for path in normal_scan_paths])

# state_to_save = {
#     'abnormal_scans': abnormal_scans,
#     'normal_scans': normal_scans,
# }

# with open('200saved_state333.pickle', 'wb') as file:
#     pickle.dump(state_to_save, file)

# %%
with open('200saved_state333.pickle', 'rb') as file:
    loaded_state = pickle.load(file)

abnormal_scans = loaded_state['abnormal_scans']
normal_scans = loaded_state['normal_scans']

# For the CT scans having presence of viral pneumonia
# assign 1, for the normal ones assign 0.
abnormal_labels = np.array([1 for _ in range(len(abnormal_scans))])
normal_labels = np.array([0 for _ in range(len(normal_scans))])

# Split data in the ratio 70-30 for training and validation.
x_train = np.concatenate((abnormal_scans[:70], normal_scans[:70]), axis=0)
y_train = np.concatenate((abnormal_labels[:70], normal_labels[:70]), axis=0)
x_val = np.concatenate((abnormal_scans[70:], normal_scans[70:]), axis=0)
y_val = np.concatenate((abnormal_labels[70:], normal_labels[70:]), axis=0)
print(
    "Number of samples in train and validation are %d and %d."
    % (x_train.shape[0], x_val.shape[0])
)
# Out:
# Number of samples in train and validation are 140 and 60.

# %%
import random
from scipy import ndimage


@tf.function
def rotate(volume):
    """Rotate the volume by a few degrees"""

    def scipy_rotate(volume):
        # define some rotation angles
        angles = [-20, -10, -5, 5, 10, 20]
        # pick angles at random
        angle = random.choice(angles)
        # rotate volume
        volume = ndimage.rotate(volume, angle, reshape=False)
        volume[volume < 0] = 0
        volume[volume > 1] = 1
        return volume

    augmented_volume = tf.numpy_function(scipy_rotate, [volume], tf.float32)
    return augmented_volume


def train_preprocessing(volume, label):
    """Process training data by rotating and adding a channel."""
    # Rotate volume
    volume = rotate(volume)
    volume = tf.expand_dims(volume, axis=3)
    return volume, label


def validation_preprocessing(volume, label):
    """Process validation data by only adding a channel."""
    volume = tf.expand_dims(volume, axis=3)
    return volume, label


print(tf.config.experimental.get_memory_info("GPU:0")["current"])
# Define data loaders.
train_loader = tf.data.Dataset.from_tensor_slices((x_train, y_train))
validation_loader = tf.data.Dataset.from_tensor_slices((x_val, y_val))


batch_size = 2
# Augment the on the fly during training.
train_dataset = (
    train_loader.shuffle(len(x_train))
    .map(train_preprocessing)
    .batch(batch_size)
    .prefetch(2)
)
# Only rescale.
validation_dataset = (
    validation_loader.shuffle(len(x_val))
    .map(validation_preprocessing)
    .batch(batch_size)
    .prefetch(2)
)
# Out:
# 0

# %%
def get_model(width=128, height=128, depth=64):
    """Build a 3D convolutional neural network model."""

    inputs = keras.Input((width, height, depth, 1))

    x = layers.Conv3D(filters=32, kernel_size=3, activation="relu")(inputs)
    x = layers.MaxPool3D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)

    x = layers.Conv3D(filters=64, kernel_size=3, activation="relu")(x)
    x = layers.MaxPool3D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)

    x = layers.Conv3D(filters=64, kernel_size=3, activation="relu")(x)
    x = layers.MaxPool3D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)

    x = layers.Conv3D(filters=128, kernel_size=3, activation="relu")(x)
    x = layers.MaxPool3D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)

    x = layers.GlobalAveragePooling3D()(x)
    x = layers.Dense(units=512, activation="relu")(x)
    x = layers.Dropout(0.5)(x)

    outputs = layers.Dense(units=1, activation="sigmoid")(x)

    # Define the model.
    model = keras.Model(inputs, outputs, name="3dcnn")
    return model


# Build model.
model = get_model(width=128, height=128, depth=64)
model.summary()
# Out:
# Model: "3dcnn"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 64, 1)  0
#                              ]
#
#  conv3d (Conv3D)             (None, 126, 126, 62, 32)  896
#
#  max_pooling3d (MaxPooling3D  (None, 63, 63, 31, 32)   0
#  )
#
#  batch_normalization (BatchN  (None, 63, 63, 31, 32)   128
#  ormalization)
#
#  conv3d_1 (Conv3D)           (None, 61, 61, 29, 64)    55360
#
#  max_pooling3d_1 (MaxPooling  (None, 30, 30, 14, 64)   0
#  3D)
#
#  batch_normalization_1 (Batc  (None, 30, 30, 14, 64)   256
#  hNormalization)
#
#  conv3d_2 (Conv3D)           (None, 28, 28, 12, 64)    110656
#
#  max_pooling3d_2 (MaxPooling  (None, 14, 14, 6, 64)    0
#  3D)
#
#  batch_normalization_2 (Batc  (None, 14, 14, 6, 64)    256
#  hNormalization)
#
#  conv3d_3 (Conv3D)           (None, 12, 12, 4, 128)    221312
#
#  max_pooling3d_3 (MaxPooling  (None, 6, 6, 2, 128)     0
#  3D)
#
#  batch_normalization_3 (Batc  (None, 6, 6, 2, 128)     512
#  hNormalization)
#
#  global_average_pooling3d (G  (None, 128)              0
#  lobalAveragePooling3D)
#
#  dense (Dense)               (None, 512)               66048
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 455,937
# Trainable params: 455,361
# Non-trainable params: 576
# _________________________________________________________________

# %%
# Показ снимков
data = train_dataset.take(1)
images, labels = list(data)[0]
images = images.numpy()
image = images[0]
print("Dimension of the CT scan is:", image.shape)
plt.imshow(np.squeeze(image[:, :, 30]), cmap="gray")

def plot_slices(num_rows, num_columns, width, height, data):
    """Plot a montage of 20 CT slices"""
    data = np.rot90(np.array(data))
    data = np.transpose(data)
    data = np.reshape(data, (num_rows, num_columns, width, height))
    rows_data, columns_data = data.shape[0], data.shape[1]
    heights = [slc[0].shape[0] for slc in data]
    widths = [slc.shape[1] for slc in data[0]]
    fig_width = 12.0
    fig_height = fig_width * sum(heights) / sum(widths)
    f, axarr = plt.subplots(
        rows_data,
        columns_data,
        figsize=(fig_width, fig_height),
        gridspec_kw={"height_ratios": heights},
    )
    for i in range(rows_data):
        for j in range(columns_data):
            axarr[i, j].imshow(data[i][j], cmap="gray")
            axarr[i, j].axis("off")
    plt.subplots_adjust(wspace=0, hspace=0, left=0, right=1, bottom=0, top=1)
    plt.show()


# Visualize montage of slices.
# 4 rows and 10 columns for 100 slices of the CT scan.
plot_slices(4, 10, 128, 128, image[:, :, :40])
# Out:
# Dimension of the CT scan is: (128, 128, 64, 1)

# %%
# Compile model.
initial_learning_rate = 0.0001
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate, decay_steps=100000, decay_rate=0.96, staircase=True
)
model.compile(
    loss="binary_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=lr_schedule),
    metrics=["acc"],
)

# Define callbacks.
checkpoint_cb = keras.callbacks.ModelCheckpoint(try_name + ".h5", save_best_only=True)
# early_stopping_cb = keras.callbacks.EarlyStopping(monitor="val_acc", patience=15)

# Train the model, doing validation at the end of each epoch
epochs = 60
model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=epochs,
    shuffle=True,
    verbose=2,
    callbacks=[
        checkpoint_cb,
    ],  # early_stopping_cb
)

print("End of Education")
# Out:
# Epoch 1/60
# 70/70 - 28s - loss: 0.7015 - acc: 0.5500 - val_loss: 0.6950 - val_acc: 0.5000 - 28s/epoch - 394ms/step
# Epoch 2/60
# 70/70 - 19s - loss: 0.6778 - acc: 0.6143 - val_loss: 0.7849 - val_acc: 0.5000 - 19s/epoch - 265ms/step
# Epoch 3/60
# 70/70 - 19s - loss: 0.6705 - acc: 0.6214 - val_loss: 0.7598 - val_acc: 0.5000 - 19s/epoch - 265ms/step
# Epoch 4/60
# 70/70 - 19s - loss: 0.6622 - acc: 0.6357 - val_loss: 0.7438 - val_acc: 0.5000 - 19s/epoch - 273ms/step
# Epoch 5/60
# 70/70 - 19s - loss: 0.6353 - acc: 0.6643 - val_loss: 1.1025 - val_acc: 0.5000 - 19s/epoch - 277ms/step
# Epoch 6/60
# 70/70 - 19s - loss: 0.6526 - acc: 0.6286 - val_loss: 0.7220 - val_acc: 0.4833 - 19s/epoch - 270ms/step
# Epoch 7/60
# 70/70 - 16s - loss: 0.6466 - acc: 0.6214 - val_loss: 0.6717 - val_acc: 0.6167 - 16s/epoch - 228ms/step
# Epoch 8/60
# 70/70 - 14s - loss: 0.6398 - acc: 0.6143 - val_loss: 0.6730 - val_acc: 0.5500 - 14s/epoch - 194ms/step
# Epoch 9/60
# 70/70 - 14s - loss: 0.6164 - acc: 0.6786 - val_loss: 1.2294 - val_acc: 0.5000 - 14s/epoch - 200ms/step
# Epoch 10/60
# 70/70 - 14s - loss: 0.6380 - acc: 0.6143 - val_loss: 0.8645 - val_acc: 0.5000 - 14s/epoch - 196ms/step
# Epoch 11/60
# 70/70 - 14s - loss: 0.6068 - acc: 0.6929 - val_loss: 0.8956 - val_acc: 0.5000 - 14s/epoch - 194ms/step
# Epoch 12/60
# 70/70 - 14s - loss: 0.5831 - acc: 0.6857 - val_loss: 0.6186 - val_acc: 0.6667 - 14s/epoch - 196ms/step
# Epoch 13/60
# 70/70 - 14s - loss: 0.5769 - acc: 0.6857 - val_loss: 0.6225 - val_acc: 0.6333 - 14s/epoch - 196ms/step
# Epoch 14/60
# 70/70 - 14s - loss: 0.5908 - acc: 0.6500 - val_loss: 0.7719 - val_acc: 0.5167 - 14s/epoch - 195ms/step
# Epoch 15/60
# 70/70 - 14s - loss: 0.5659 - acc: 0.7000 - val_loss: 0.7363 - val_acc: 0.5500 - 14s/epoch - 195ms/step
# Epoch 16/60
# 70/70 - 14s - loss: 0.5428 - acc: 0.7214 - val_loss: 0.6389 - val_acc: 0.6000 - 14s/epoch - 197ms/step
# Epoch 17/60
# 70/70 - 14s - loss: 0.5765 - acc: 0.7214 - val_loss: 0.7699 - val_acc: 0.6333 - 14s/epoch - 195ms/step
# Epoch 18/60
# 70/70 - 14s - loss: 0.5185 - acc: 0.7429 - val_loss: 0.5856 - val_acc: 0.7000 - 14s/epoch - 196ms/step
# Epoch 19/60
# 70/70 - 14s - loss: 0.5485 - acc: 0.7071 - val_loss: 0.6077 - val_acc: 0.6333 - 14s/epoch - 196ms/step
# Epoch 20/60
# 70/70 - 14s - loss: 0.5125 - acc: 0.7286 - val_loss: 0.6262 - val_acc: 0.6667 - 14s/epoch - 196ms/step
# Epoch 21/60
# 70/70 - 14s - loss: 0.4860 - acc: 0.7571 - val_loss: 0.8790 - val_acc: 0.5167 - 14s/epoch - 195ms/step
# Epoch 22/60
# 70/70 - 14s - loss: 0.4819 - acc: 0.7929 - val_loss: 0.5795 - val_acc: 0.6833 - 14s/epoch - 195ms/step
# Epoch 23/60
# 70/70 - 14s - loss: 0.6008 - acc: 0.6643 - val_loss: 0.8042 - val_acc: 0.5667 - 14s/epoch - 195ms/step
# Epoch 24/60
# 70/70 - 14s - loss: 0.4994 - acc: 0.7714 - val_loss: 0.5888 - val_acc: 0.6667 - 14s/epoch - 195ms/step
# Epoch 25/60
# 70/70 - 14s - loss: 0.4773 - acc: 0.7429 - val_loss: 1.0327 - val_acc: 0.5167 - 14s/epoch - 195ms/step
# Epoch 26/60
# 70/70 - 14s - loss: 0.5147 - acc: 0.7071 - val_loss: 0.5858 - val_acc: 0.6500 - 14s/epoch - 195ms/step
# Epoch 27/60
# 70/70 - 14s - loss: 0.5451 - acc: 0.7286 - val_loss: 0.6147 - val_acc: 0.6667 - 14s/epoch - 195ms/step
# Epoch 28/60
# 70/70 - 14s - loss: 0.5064 - acc: 0.7000 - val_loss: 0.6193 - val_acc: 0.6500 - 14s/epoch - 196ms/step
# Epoch 29/60
# 70/70 - 14s - loss: 0.4517 - acc: 0.7714 - val_loss: 0.6434 - val_acc: 0.6000 - 14s/epoch - 196ms/step
# Epoch 30/60
# 70/70 - 14s - loss: 0.4651 - acc: 0.7714 - val_loss: 0.8473 - val_acc: 0.6167 - 14s/epoch - 196ms/step
# Epoch 31/60
# 70/70 - 14s - loss: 0.5017 - acc: 0.7357 - val_loss: 0.5607 - val_acc: 0.6833 - 14s/epoch - 196ms/step
# Epoch 32/60
# 70/70 - 14s - loss: 0.4434 - acc: 0.7643 - val_loss: 0.6731 - val_acc: 0.6167 - 14s/epoch - 195ms/step
# Epoch 33/60
# 70/70 - 14s - loss: 0.4535 - acc: 0.7429 - val_loss: 1.0613 - val_acc: 0.5833 - 14s/epoch - 195ms/step
# Epoch 34/60
# 70/70 - 14s - loss: 0.4398 - acc: 0.7714 - val_loss: 0.7370 - val_acc: 0.5833 - 14s/epoch - 196ms/step
# Epoch 35/60
# 70/70 - 14s - loss: 0.4200 - acc: 0.7929 - val_loss: 0.8924 - val_acc: 0.6000 - 14s/epoch - 195ms/step
# Epoch 36/60
# 70/70 - 14s - loss: 0.4342 - acc: 0.7786 - val_loss: 0.5627 - val_acc: 0.6667 - 14s/epoch - 196ms/step
# Epoch 37/60
# 70/70 - 14s - loss: 0.4777 - acc: 0.7643 - val_loss: 0.6755 - val_acc: 0.6167 - 14s/epoch - 196ms/step
# Epoch 38/60
# 70/70 - 14s - loss: 0.4062 - acc: 0.8143 - val_loss: 0.8283 - val_acc: 0.6333 - 14s/epoch - 195ms/step
# Epoch 39/60
# 70/70 - 14s - loss: 0.3849 - acc: 0.7786 - val_loss: 1.0547 - val_acc: 0.5833 - 14s/epoch - 196ms/step
# Epoch 40/60
# 70/70 - 14s - loss: 0.3944 - acc: 0.7929 - val_loss: 0.5774 - val_acc: 0.7000 - 14s/epoch - 196ms/step
# Epoch 41/60
# 70/70 - 14s - loss: 0.3803 - acc: 0.8071 - val_loss: 0.5801 - val_acc: 0.6667 - 14s/epoch - 196ms/step
# Epoch 42/60
# 70/70 - 14s - loss: 0.4609 - acc: 0.7643 - val_loss: 0.5888 - val_acc: 0.7000 - 14s/epoch - 196ms/step
# Epoch 43/60
# 70/70 - 14s - loss: 0.3999 - acc: 0.7571 - val_loss: 0.6243 - val_acc: 0.7167 - 14s/epoch - 197ms/step
# Epoch 44/60
# 70/70 - 14s - loss: 0.3495 - acc: 0.8357 - val_loss: 0.9832 - val_acc: 0.5667 - 14s/epoch - 196ms/step
# Epoch 45/60
# 70/70 - 14s - loss: 0.2968 - acc: 0.8786 - val_loss: 0.6116 - val_acc: 0.6333 - 14s/epoch - 196ms/step
# Epoch 46/60
# 70/70 - 14s - loss: 0.4083 - acc: 0.8000 - val_loss: 1.2548 - val_acc: 0.6167 - 14s/epoch - 196ms/step
# Epoch 47/60
# 70/70 - 14s - loss: 0.4114 - acc: 0.7786 - val_loss: 1.2660 - val_acc: 0.5167 - 14s/epoch - 196ms/step
# Epoch 48/60
# 70/70 - 14s - loss: 0.3309 - acc: 0.8286 - val_loss: 0.6076 - val_acc: 0.6500 - 14s/epoch - 196ms/step
# Epoch 49/60
# 70/70 - 14s - loss: 0.3157 - acc: 0.8714 - val_loss: 0.8860 - val_acc: 0.6333 - 14s/epoch - 196ms/step
# Epoch 50/60
# 70/70 - 14s - loss: 0.4199 - acc: 0.7714 - val_loss: 0.5864 - val_acc: 0.7167 - 14s/epoch - 196ms/step
# Epoch 51/60
# 70/70 - 14s - loss: 0.3571 - acc: 0.8286 - val_loss: 1.4792 - val_acc: 0.5667 - 14s/epoch - 196ms/step
# Epoch 52/60
# 70/70 - 14s - loss: 0.3438 - acc: 0.8214 - val_loss: 0.9177 - val_acc: 0.6333 - 14s/epoch - 196ms/step
# Epoch 53/60
# 70/70 - 14s - loss: 0.3433 - acc: 0.8214 - val_loss: 0.6617 - val_acc: 0.6833 - 14s/epoch - 196ms/step
# Epoch 54/60
# 70/70 - 14s - loss: 0.3025 - acc: 0.8786 - val_loss: 0.6012 - val_acc: 0.7167 - 14s/epoch - 197ms/step
# Epoch 55/60
# 70/70 - 14s - loss: 0.3867 - acc: 0.8071 - val_loss: 0.5677 - val_acc: 0.7500 - 14s/epoch - 196ms/step
# Epoch 56/60
# 70/70 - 14s - loss: 0.3076 - acc: 0.8643 - val_loss: 1.1563 - val_acc: 0.6000 - 14s/epoch - 196ms/step
# Epoch 57/60
# 70/70 - 14s - loss: 0.3160 - acc: 0.8357 - val_loss: 0.6398 - val_acc: 0.6833 - 14s/epoch - 196ms/step
# Epoch 58/60
# 70/70 - 14s - loss: 0.3485 - acc: 0.8500 - val_loss: 0.6533 - val_acc: 0.7000 - 14s/epoch - 197ms/step
# Epoch 59/60
# 70/70 - 14s - loss: 0.2948 - acc: 0.8714 - val_loss: 0.6549 - val_acc: 0.6500 - 14s/epoch - 196ms/step
# Epoch 60/60
# 70/70 - 14s - loss: 0.2214 - acc: 0.9143 - val_loss: 0.6245 - val_acc: 0.7500 - 14s/epoch - 196ms/step
# End of Education

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 3))
ax = ax.ravel()

for i, metric in enumerate(["acc", "loss"]):
    ax[i].plot(model.history.history[metric])
    ax[i].plot(model.history.history["val_" + metric])
    ax[i].set_title("Model {}".format(metric))
    ax[i].set_xlabel("epochs")
    ax[i].set_ylabel(metric)
    ax[i].legend(["train", "val"])

# %%
# Load best weights.
model.load_weights(try_name+".h5")
prediction = model.predict(np.expand_dims(x_val[0], axis=0))[0]
scores = [1 - prediction[0], prediction[0]]

class_names = ["normal", "abnormal"]
for score, name in zip(scores, class_names):
    print(
        "This model is %.2f percent confident that CT scan is %s"
        % ((100 * score), name)
    )
    print("And this is " + str(y_val[0]))


datagen = ImageDataGenerator()
generator = datagen.flow(x_val, batch_size=batch_size, shuffle=False)

y_pred = model.predict_generator(generator, steps=np.ceil(len(x_val) / batch_size))


y_pred_binary = (y_pred > 0.5).astype(int)


# метрики
accuracy = accuracy_score(y_val, y_pred_binary)
precision = precision_score(y_val, y_pred_binary)
recall = recall_score(y_val, y_pred_binary)

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")


model.save(try_name+"_save", save_format="tf")

plt.show()
# Out:
# 1/1 [==============================] - 0s 166ms/step
# This model is 25.11 percent confident that CT scan is normal
# And this is 1
# This model is 74.89 percent confident that CT scan is abnormal
# And this is 1
# c:\Develop\miniconda\envs\py310\lib\site-packages\keras_preprocessing\image\numpy_array_iterator.py:129: UserWarning: NumpyArrayIterator is set to use the data format convention "channels_last" (channels on axis 3), i.e. expected either 1, 3, or 4 channels on axis 3. However, it was passed an array with shape (60, 128, 128, 64) (64 channels).
#   warnings.warn('NumpyArrayIterator is set to use the '
# C:\Users\danek\AppData\Local\Temp\ipykernel_9952\3670540818.py:18: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   y_pred = model.predict_generator(generator, steps=np.ceil(len(x_val) / batch_size))
# Accuracy: 0.6833333333333333
# Precision: 0.7037037037037037
# Recall: 0.6333333333333333
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: iz3_buffed_6_save\assets
# INFO:tensorflow:Assets written to: iz3_buffed_6_save\assets
